# %%
import os

IGNORE = {"venv", ".git", "__pycache__", "myenv","node_modules","backvenv"}  # folders to skip

def print_dir_tree(root_dir, prefix=""):
    entries = [e for e in os.listdir(root_dir) if e not in IGNORE]
    for i, item in enumerate(entries):
        path = os.path.join(root_dir, item)
        connector = "└── " if i == len(entries) - 1 else "├── "
        print(prefix + connector + item)
        if os.path.isdir(path):
            extension = "    " if i == len(entries) - 1 else "│   "
            print_dir_tree(path, prefix + extension)

# Example usage
project_root = "/home/ml/Documents/SmartHealth-LLM"
print_dir_tree(project_root)
# Out:
# ├── scripts
# │   ├── scrapers
# │   │   ├── web_scrapers.py
# │   │   ├── main.py
# │   │   └── web_scraper2.py
# │   ├── update_readme.py
# │   ├── model.py
# │   ├── build_faiss_db.py
# │   └── build_disease_db.py
# ├── evaluation
# │   └── evaluate_rag_symptom.py
# ├── requirements.txt
# ├── logo.png
# ├── skin.png
# ├── Dockerfile
# ├── README.md
# ├── notebook
# │   ├── skin_disease_prediction.ipynb
# │   ├── catboost_info
# │   │   ├── catboost_training.json
# │   │   ├── learn_error.tsv
# │   │   ├── tmp
# │   │   │   ├── cat_feature_index.b92be4a3-6d26c876-c529c985-6bb3a081.tmp
# │   │   │   ├── cat_feature_index.9fa11a0d-2e9dbd96-4b2b8c5d-91bc4185.tmp
# │   │   │   ├── cat_feature_index.9ac1f2c7-518bf965-2d5891c5-7bdbfe05.tmp
# │   │   │   └── cat_feature_index.7bec41d3-6b6bcf45-537e8469-a414ed.tmp
# │   │   ├── learn
# │   │   │   └── events.out.tfevents
# │   │   └── time_left.tsv
# │   └── web_scrapping.ipynb
# ├── .gitignore
# ├── image.png
# ├── backend
# │   ├── config.py
# │   ├── services
# │   │   └── image_classifier.py
# │   ├── .env
# │   ├── main.py
# │   ├── utils
# │   │   ├── llm.py
# │   │   ├── embeddings.py
# │   │   ├── symtom_checker.py
# │   │   ├── preprocessing.py
# │   │   ├── symptoms_extractor.py
# │   │   └── image_preprocessing.py
# │   ├── requirements.txt
# │   ├── data
# │   │   ├── archive
# │   │   │   └── medquad.csv
# │   │   ├── mayo_diseases.csv
# │   │   ├── labels.json
# │   │   ├── updated_df.csv
# │   │   ├── test.json
# │   │   └── Vector
# │   │       ├── disease_faiss_db
# │   │       │   ├── index.faiss
# │   │       │   └── index.pkl
# │   │       └── symptom_faiss_db
# │   │           └── index.faiss
# │   │               ├── index.faiss
# │   │               └── index.pkl
# │   ├── models
# │   │   └── skin_disease_model.h5
# │   └── agents
# │       ├── image_agent.py
# │       ├── decider_agent.py
# │       ├── disease_info_gent.py
# │       └── symptom_agent.py
# ├── chatbot.png
# ├── s.ipynb
# ├── LICENSE
# ├── .gitattributes
# └── frontend
#     ├── public
#     │   ├── logo512.png
#     │   ├── logo192.png
#     │   ├── robots.txt
#     │   ├── manifest.json
#     │   ├── index.html
#     │   └── favicon.ico
#     ├── package-lock.json
#     ├── README.md
#     ├── .gitignore
#     ├── src
#     │   ├── api.ts
#     │   ├── App.css
#     │   ├── ChatPage.tsx
#     │   ├── App.test.tsx
#     │   ├── logo.svg
#     │   ├── ChatPage.css
#     │   ├── reportWebVitals.ts
#     │   ├── react-app-env.d.ts
#     │   ├── App.tsx
#     │   ├── index.tsx
#     │   ├── index.css
#     │   └── setupTests.ts
#     ├── tsconfig.json
#     └── package.json
